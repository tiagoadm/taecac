# %%
# Bibliotecas

from sqlalchemy import create_engine
import pandas as pd

# Dataset do UCI

df = pd.read_excel(r'C:\Users\tdiog\Nextcloud\Documents\ProDEI\TAECAC\Online Retail.xlsx')

# Análise rápida às variáveis do dataset

df.describe(include='all')
# Out:
# <ipython-input-1-5391d3e4df3e>:10: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# first         NaN       NaN                                 NaN
# last          NaN       NaN                                 NaN
# mean          NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# ...

# %% [markdown]
# É possível verificar que existem valores negativos nas variáveis Quantity e UnitPrice, e valores máximos muito superiores à média e desvio-padrão, que indica que existem outliers. Será necessário filtrar os dados para remover valores negativos e outliers.
#
# Tipicamente, estes valores representam códigos e devem ser ignorados.

# %%
# Contagem de valores em branco por variável

df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Será necessário remover todas as linhas em que o CustomerID e a Description se encontram vazios.

# %%
# Envio para postgreSQL

engine = create_engine('postgresql://postgres:password@192.168.1.70:5432/postgres')
df.to_sql('uci_database', engine)
